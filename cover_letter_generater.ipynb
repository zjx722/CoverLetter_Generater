# %%
import pdfkit
from datetime import date

# %%
def cover_letter(company_name, quant_OR_ds_OR_mEng = 'quant', position= 'no', location ='the San Francisco area', specific_comments='no'):
    

    today = date.today()
    format_date= today.strftime("%B %d, %Y")
    title_date = today.strftime("%Y%m%d")
    
    options = {
    'page-size': 'Letter',
    'margin-top': '1.3in',
    'margin-right': '1.0in',
    'margin-bottom': '1.0in',
    'margin-left': '1.0in',
    'encoding': "UTF-8",
    'custom-header' : [
        ('Accept-Encoding', 'gzip')
    ],
    'cookie': [
        ('cookie-name1', 'cookie-value1'),
        ('cookie-name2', 'cookie-value2'),
    ],
    'no-outline': None
    }
    
    
    title = f"""
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style='font-size: 22px; line-height: 115%; color: black; font-family: "Times New Roman", Times, serif;'>&nbsp;</span></p>
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">{format_date}</span></span></span></p>
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><br></p>
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">To {company_name} recruiting team:</span></span></span></p>
        <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
        """
        
    if position is 'no':
        introduction  = f"""
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;">As I acknowledged the full-time opportunity at {company_name}, I decided to introduce my candidacy in this cover letter.&nbsp;</span></span></p>
        
        """
    if position is not 'no':
        introduction  = f"""
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;">As I acknowledged the full-time opportunity as {position} at {company_name}, I decided to introduce my candidacy in this cover letter.&nbsp;</span></span></p>
        
        """
    
    if quant_OR_ds_OR_mEng == 'quant': 
        skill = f"""
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><br></span></p>
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;">I recently graduated from UC Berkeley, Master of Financial Engineering Program also hold Engineering Ph.D. from Tsinghua University. I am actively seeking employment with firms in {location}. I believe my skills and experience listed below are a very good match with the<span style="color: rgb(51, 51, 51);">&nbsp;requirements of this job.</span></span></span></p>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">1+ year industry experience of quantitative finance and programming skills: Familiarity with financial modeling, asset allocation strategies, alpha research, machine learning and optimization method; Proficient of Python, R and MySQL.</span><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="color: rgb(51, 51, 51); background: white;">Strong academic performance&nbsp;</span><span style="color: black;">in Ph.D. and MFE program: Topics cover statistical models, ESG factors analysis, recommendation system and numerical analysis; 5+ publications in international journals, 3+ presentations in international conferences.</span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Enthusiasm and creativity to work and learning in financial industry: Adept at working effectively both collaboratively and independently to meet strict deadlines; Strong capability of problem solving, communication and team work.</span></span></span></li>
        </ul>
        </div>
        
        """
        
    if quant_OR_ds_OR_mEng == 'ds': 
        
        skill = f"""
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><br></span></p>
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;">I recently graduated from UC Berkeley, Master of Financial Engineering Program and also hold Engineering Ph.D. from Tsinghua University. I am enthusiastic in data science and actively seeking employment with firms in {location}. I believe my skills and experience listed below are a very good match with the<span style="color: rgb(51, 51, 51);">&nbsp;requirements of this job.</span></span></span></p>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif; color: black; border: 1pt none windowtext; padding: 0in; background: white;'>Solid foundation of data analysis and programming: Industrial experience with statistical models, machine learning and natural language processing(NLP); Strong skills with Python, R, MySQL and proficient in data manipulation and AB testing.</span><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="color: black; border: 1pt none windowtext; padding: 0in; background: white;">Extensive data modelling experience during Ph.D. and MFE academic research: Topics cover recommendation system, neural networks and numerical analysis; 5+ publications in international journals, 3+ presentations in international conferences and workshops.</span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="color: black; border: 1pt none windowtext; padding: 0in; background: white;">Enthusiasm and creativity to work and learning of new techniques: Adept at working effectively both collaboratively and independently to meet strict deadlines.</span></span></span><span style='font-size: 22px; font-family: "Times New Roman", Times, serif; color: black; background: white;'>&nbsp;</span></li>
        </ul>
        </div>
        
        """
        
    if quant_OR_ds_OR_mEng == 'mEng': 
        skill = f"""
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><br></span></p>
        <p style='font-size: 16px; font-family: "Times New Roman", serif; margin: 0in 0in 0.0001pt; color: black; line-height: 1.15;'><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"> I recently graduated from UC Berkeley, Master of Financial Engineering Program and also hold Engineering Ph.D. from Tsinghua University. I am enthusiastic in software engineering specialized in machine learning and actively seeking employment with firms in {location}.  I believe my skills and experience listed below are a very good match with the<span style="color: rgb(51, 51, 51);">&nbsp;requirements of this job.</span></span></span></p>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif; color: black; border: 1pt none windowtext; padding: 0in; background: white;'> Solid foundation of machine learning and programming: Industrial experience with statistical models, deep learning and natural language processing (NLP); Proficient with Python, R, MySQL and solved 400+ LeetCode algorithm problems.</span><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="color: black; border: 1pt none windowtext; padding: 0in; background: white;"> Extensive research experience during Ph.D. and MFE academic projects: Topics cover recommendation system, neural networks and numerical analysis; 5+ publications in international journals, 3+ presentations in international conferences and workshops. </span></span></span></li>
        </ul>
        </div>
        <div style='margin:0in;margin-bottom:.0001pt;font-size:16px;font-family:"Calibri",sans-serif;'>
        <ul style="margin-bottom:0in;list-style-type: undefined;">
        <li style="margin: 0in 0in 0.0001pt; font-size: 16px; font-family: Calibri, sans-serif; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="color: black; border: 1pt none windowtext; padding: 0in; background: white;">Enthusiasm and creativity to work and learning of new techniques: Adept at working effectively both collaboratively and independently to meet strict deadlines.</span></span></span><span style='font-size: 22px; font-family: "Times New Roman", Times, serif; color: black; background: white;'>&nbsp;</span></li>
        </ul>
        </div>
        
        """
         
        
        
    if specific_comments =='no':
        
        if quant_OR_ds_OR_mEng == 'ds':
            ending =  f"""
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Today, I remain more dedicated than ever to becoming a valuable data scientist who can solve complex problems with huge datasets and make a positive impact using my statistical knowledge. {company_name} is the place where I know I can thrive.&nbsp;</span><span style="line-height: 115%; color: black;">I have enclosed my resume for your review. I would like the opportunity to share more about my qualifications and the ways in which I can contribute to the team.&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Sincerely,<br>Jiaxin (Jasmine) Zhao</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">LinkedIn:&nbsp;</span><a href="https://www.linkedin.com/in/jiaxin-zhao-controlscience"><span style="line-height: 115%;">https://www.linkedin.com/in/jiaxin-zhao-controlscience</span></a></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="color: rgb(0, 0, 0);"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%;">Email:&nbsp;</span><a href="mailto:jiaxin_zhao@mfe.berkeley.edu"><span style="line-height: 115%; text-decoration: none;">jiaxin_zhao@mfe.berkeley.edu</span></a></span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">Tel: +1(510) 501-2763</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif;'>&nbsp;</span></p>

            """
        if quant_OR_ds_OR_mEng == 'quant':
            ending =  f"""
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Today, I remain more dedicated than ever to becoming a valuable quantitative researcher who can solve complex problems with huge datasets and make a positive impact using financial engineering knowledge. {company_name} is the place where I know I can thrive.&nbsp;</span><span style="line-height: 115%; color: black;">I have enclosed my resume for your review. I would like the opportunity to share more about my qualifications and the ways in which I can contribute to the team.&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Sincerely,<br>Jiaxin (Jasmine) Zhao</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">LinkedIn:&nbsp;</span><a href="https://www.linkedin.com/in/jiaxin-zhao-controlscience"><span style="line-height: 115%;">https://www.linkedin.com/in/jiaxin-zhao-controlscience</span></a></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="color: rgb(0, 0, 0);"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%;">Email:&nbsp;</span><a href="mailto:jiaxin_zhao@mfe.berkeley.edu"><span style="line-height: 115%; text-decoration: none;">jiaxin_zhao@mfe.berkeley.edu</span></a></span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">Tel: +1(510) 501-2763</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif;'>&nbsp;</span></p>

            """
            
            
        if quant_OR_ds_OR_mEng == 'mEng':
            ending =  f"""
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Today, I remain more dedicated than ever to becoming a valuable machine learning engineer who can solve complex problems with huge datasets and make a positive impact using engineering knowledge. {company_name} is the place where I know I can thrive.&nbsp;</span><span style="line-height: 115%; color: black;">I have enclosed my resume for your review. I would like the opportunity to share more about my qualifications and the ways in which I can contribute to the team.&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Sincerely,<br>Jiaxin (Jasmine) Zhao</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">LinkedIn:&nbsp;</span><a href="https://www.linkedin.com/in/jiaxin-zhao-controlscience"><span style="line-height: 115%;">https://www.linkedin.com/in/jiaxin-zhao-controlscience</span></a></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="color: rgb(0, 0, 0);"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%;">Email:&nbsp;</span><a href="mailto:jiaxin_zhao@mfe.berkeley.edu"><span style="line-height: 115%; text-decoration: none;">jiaxin_zhao@mfe.berkeley.edu</span></a></span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">Tel: +1(510) 501-2763</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif;'>&nbsp;</span></p>

            """
            
            
    if specific_comments != 'no':
        ending =  f"""
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">{specific_comments}&nbsp;</span><span style="line-height: 115%; color: black;">I have enclosed my resume for your review. I would like the opportunity to share more about my qualifications and the ways in which I can contribute to the team.&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; line-height: 1.15;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">&nbsp;</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%; color: black;">Sincerely,<br>Jiaxin (Jasmine) Zhao</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><br></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">LinkedIn:&nbsp;</span><a href="https://www.linkedin.com/in/jiaxin-zhao-controlscience"><span style="line-height: 115%;">https://www.linkedin.com/in/jiaxin-zhao-controlscience</span></a></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style="color: rgb(0, 0, 0);"><span style="font-family: 'Times New Roman', Times, serif;"><span style="line-height: 115%;">Email:&nbsp;</span><a href="mailto:jiaxin_zhao@mfe.berkeley.edu"><span style="line-height: 115%; text-decoration: none;">jiaxin_zhao@mfe.berkeley.edu</span></a></span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15; background: white;"><span style="font-size: 22px;"><span style='font-family: "Times New Roman", Times, serif; color: rgb(0, 0, 0);'><span style="line-height: 115%;">Tel: +1(510) 501-2763</span></span></span></p>
            <p style="font-size: 16px; font-family: Calibri, sans-serif; margin: 0in 0in 0.0001pt; text-align: justify; line-height: 1.15;"><span style='font-size: 22px; font-family: "Times New Roman", Times, serif;'>&nbsp;</span></p>

            """
            
        

    body = title +introduction + skill + ending
    
    pdfkit.from_string(body, '/Users/jiaxinzhao/Documents/0.FullTime/2.my_coverletter/CoverLetter_{}_{}.pdf'.format(company_name,title_date), options=options) 
    
    return

# %%
company_name = input("Enter company name : ")

quant_OR_ds = input('For quant position, enter quant; For data science position, enter ds; For Machine learning Eng, enter mEng:')

position = input('Enter the position:(ok to enter no)')
 
location = input('Enter location after in (the San Francisco area): ')

specific_comments = input('Do you have any specific notes at the begining of last paragraph? no(default):')


cover_letter(company_name, quant_OR_ds, position, location , specific_comments)
# Out:
# Enter company name : Lazard Asset Management
# For quant position, enter quant; For data science position, enter ds; For Machine learning Eng, enter mEng:quant
# Enter the position:(ok to enter no)Quantitative Researcher
# Enter location after in (the San Francisco area): Boston
# Do you have any specific notes at the begining of last paragraph? no(default):no
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
